# %% [markdown]
# # VL09 - The Transformer architecture (MiniGPT)
# In this seminar, we will implement transformer-based language model "MiniGPT". This MiniGPT is based on a Decoder Transformer block, causal self-attention, and a language modeling head.
#
# We will go over how to prepare data for the training, how to define the self-attention component, the transformer block and the language model head.

# %%
import math
import random
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F

from datasets import load_dataset, load_from_disk
from tqdm.notebook import tqdm

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device

# %% [markdown]
# ## 1. Prepare dataset
#
# We come back to our WikiText-2-raw-v1 dataset, and use it to train our small model.
#
# We keep the tokenizer extremely simple:
# - split on whitespace and punctuation, keeping puncutation so that the language model learns language structure
# - build a small vocab of the most frequent tokens
# This keeps training reasonably *fast* for our seminar.
#
# We then transform the dataset to a long stream of tokens. No need to learn by sentences or even documents. We fit tokens in the context windows, consuming them in chunks.
#
# ### 1.1. Download and load dataset
# Small dataset, 2M tokens.
# ````bash
# $ python scripts/download_dataset.py "Salesforce/wikitext" "wikitext-2-raw-v1" data/wikitext-103-raw-v1
# ````
#
# Large dataset, 103M tokens.
# ````bash
# $ python scripts/download_dataset.py "Salesforce/wikitext" "wikitext-103-raw-v1" data/wikitext-103-raw-v1
# ````

# %%
ds = load_from_disk("../../data/wikitext-2-raw-v1")
train_raw = ds["train"]["text"]
eval_raw = ds["validation"]["text"]
ds

# %% [markdown]
# ### 1.2 Turning datasets into a long stream of tokens
# Instead of splitting the dataset into sentences, we take the whole dataset and consume it as a stream of tokens. Punctuations are part of the tokens so the transformer architecture should be able to learn (given enough data) language structure, context switching directly from the data.

# %%
import re
import spacy

TOKEN_RE = re.compile(
    r"[a-zA-Z]+(?:'[a-zA-Z]+)?|"  # words with optional apostrophe (don't, i'm)
    r"[.,!?;:()\-]"               # punctuation tokens as standalone
)

def clean_wikitext(lines):
    """Remove obvious wikitext artifacts."""
    for t in lines:
        t = t.strip()
        if not t:
            continue
        if re.match(r"^=+\s.*\s=+$", t):       # headings
            continue
        t = re.sub(r"\{\{.*?\}\}", "", t)      # {{ ... }}
        t = re.sub(r"\[\[|\]\]", "", t)        # [[ ]]
        yield t

def simple_tokenize(text):
    # find all words + punctuation, as separate tokens
    return TOKEN_RE.findall(text.lower())

def to_stream(cleaned_lines):
    stream = []
    for line in cleaned_lines:
        stream.extend(simple_tokenize(line))
    return stream

to_stream(["In the end, i don't know what to do!", "All is done"])

# %%
# We transform the train and eval datasets into to a long stream of tokens
train_stream = to_stream(clean_wikitext(train_raw))
eval_stream  = to_stream(clean_wikitext(eval_raw))

len(train_stream), len(eval_stream)

# %% [markdown]
# ### 1.3. Build the vocabulary
# We build the vocabulary with the most common tokens in the training token stream. We limit this to speed up training and avoid the long tail of the count distribution.

# %%
# Let's build the vocabulary
vocab_counts = Counter(train_stream)
most_common = vocab_counts.most_common(15000)  # or 10000
itos = ["<pad>", "<unk>"] + [w for w,_ in most_common]
stoi = {w:i for i,w in enumerate(itos)}
vocab_size = len(itos)
print ("Word types: ", len(vocab_counts) )
print ("Vocabulary size: ", vocab_size)
# let's see if our indexing works
print ("Index of <unk>: ", stoi["<unk>"])
print ("Word in Index 1: ", itos[1])

# %%
most_common[1:50]

# %% [markdown]
# ### 1.4. Encode the streams into array of vocab indexes
# With the vocabulary built - and having an index for each token in our vocab - we encode our stream of tokens into a stream of token ids.

# %%
def encode_stream(stream, stoi):
    """Map each token to an integer id."""
    stream_ids = [stoi.get(tok, stoi["<unk>"]) for tok in stream]
    return stream_ids

train_id_stream = encode_stream(train_stream, stoi)
eval_id_stream  = encode_stream(eval_stream,  stoi)

# to inspect an example:
print (encode_stream(["the", "game"], stoi))


len(train_id_stream), len(eval_id_stream)

# %% [markdown]
# **Quick check**: How many unks do we have in our encoded training dataset?

# %%
unk_index = stoi["<unk>"]

total_tokens = len(train_id_stream)
unk_tokens = sum(1 for t in train_id_stream if t == unk_index)

unk_ratio = unk_tokens / total_tokens
print("Training - N tokens: ", total_tokens)
print("Training - N <unk>", unk_tokens)
print("Training - <unk> ratio", unk_ratio)

# %% [markdown]
# ### 1.5 Converting the encoded token stream into context windows
# Our decoder-only Transformer does not learn from sentences or documents.
# Instead, it learns by predicting the next token inside a **fixed-size context window**
# (e.g., 64 tokens). This window is the model’s *entire world* during training.
#
# To prepare the data in this format, we take our long, continuous stream of
# token IDs and slice it into **non-overlapping chunks** of length `seq_len`.

# %%
seq_len = 64
pad_idx = stoi["<pad>"]

def stream_to_windows(stream_ids, seq_len, pad_idx):
    """Create fixed-length, non-overlapping training blocks."""
    sequences = []
    for i in range(0, len(stream_ids), seq_len): # i, i+seq_length, i+seq_length*2...
        chunk = stream_ids[i:i+seq_len]
        if len(chunk) < seq_len:
            chunk = chunk + [pad_idx] * (seq_len - len(chunk))
        sequences.append(torch.tensor(chunk, dtype=torch.long))
    return sequences

# %%
train_seqs = stream_to_windows(train_id_stream, seq_len, pad_idx)
eval_seqs  = stream_to_windows(eval_id_stream,  seq_len, pad_idx)


len(train_seqs), len(eval_seqs)

# %% [markdown]
# ## 2. Mini GPT model
# In this section we build a very small **decoder-only Transformer**, following the same architectural ideas as GPT-style language models.
# The full model has three components:
#
# 1. **Causal Self-Attention** – the mechanism that lets the model attend only to past tokens.
# 2. **A Decoder Transformer Block** – attention + feed-forward network + residual connections + layer norm.
# 3. **Mini GPT** – token embedding -> transformer blocks -> linear LM head for next-token prediction.
#
# Each piece is intentionally small so that we can train it live during the seminar.

# %% [markdown]
# ### 2.1 Causal Self-Attention
# Self-attention lets each token look at other tokens in the same context window. For a language model, this attention must be **causal**:
# each token can only attend to *previous* positions, never future ones.
#
# Practically, this module:
#
# - projects the input to queries, keys, and values
# - computes dot-product attention
# - applies a causal mask (upper triangular mask)
# - combines the heads
# - returns a transformed representation with the same dimensionality
#
# This gives the model a way to blend information from earlier tokens.

# %%
class CausalSelfAttention(nn.Module):
    def __init__(self, d_model, num_heads):
        super().__init__()
         # Number of attention heads.
        self.num_heads = num_heads
        
        # Each head works on a smaller part of the embedding.
        # Example: d_model = 128, num_heads = 4 -> d_head = 32.
        self.d_head = d_model // num_heads

        # One linear layer produces queries, keys, and values at once.
        #  Input shape :  (B, T, d_model)
        #  Output shape:  (B, T, 3 * d_model)    
        # We later split this output into Q, K, V
        self.qkv = nn.Linear(d_model, 3 * d_model)

        # After all heads produce their outputs, we combine them back
        # into one d_model-dimensional representation per token.
        self.out = nn.Linear(d_model, d_model)

    
    def forward(self, x, pad_mask=None):
        # B = batch size
        # T = sequence length
        # C = model dimension (d_model)
        B, T, C = x.shape

        # The linear layer gives us all three at once, so we split it.
        # the output (B, T, 3 * d_model) is split in 3 parts along the last dim (-1)
        q, k, v = self.qkv(x).chunk(3, dim=-1)

        # Multi-head attention needs several independent attention heads   
        # Before:          q, k, v have shape (B, T, C)
        # After view:      (B, T, num_heads, d_head)
        # --
        # Attention is computed independently for each head.
        # We therefore move the head dimension before the sequence dimension:  
        # --
        # After transpose: (B, num_heads, T, d_head)
        q = q.view(B, T, self.num_heads, self.d_head).transpose(1, 2)
        k = k.view(B, T, self.num_heads, self.d_head).transpose(1, 2)
        v = v.view(B, T, self.num_heads, self.d_head).transpose(1, 2)

        # Compute pairwise attention scores between all tokens.
        # PyTorch/CUDA performs this batched matrix multiplication
        # for all sequences and all heads in parallel.
        # Result:  (B, num_heads, T, T)
        att = (q @ k.transpose(-2, -1)) / math.sqrt(self.d_head)
    
        # Causal mask (future tokens blocked)
        #  torch.tril creates a lower-triangular matrix, and .bool() turn them True/False
        causal = torch.tril(torch.ones(T, T, device=x.device)).bool()
        #  we apply the mask 
        att = att.masked_fill(~causal, float('-inf'))

        # Padding tokens are not real words.
        # Other tokens should not attend to them.
        #
        # pad_mask shape before: (B, T)
        # We reshape it to: (B, 1, 1, T)
        #     
        # This is so we do not compute attention to paddings! -inf is excluded
        if pad_mask is not None:
            # pad_mask: (B, T), True where pad
            pad_mask = pad_mask.unsqueeze(1).unsqueeze(1)   # (B,1,1,T)
            att = att.masked_fill(pad_mask, float('-inf'))

        # Convert attention scores into probabilities
        att = F.softmax(att, dim=-1)
        # Use attention to mix it with values to get the output
        y = att @ v

        # Concatenate the heads back together
        #  Currently:
        #   y shape = (B, num_heads, T, d_head)
        #  We want:
        #   y shape = (B, T, C)
        # That means putting all heads back side by side.
        y = y.transpose(1, 2).contiguous().view(B, T, C)

        # W^O keeps the same shape (B, T, C) but learns how to
        # combine information coming from the different heads.        
        return self.out(y)

# %% [markdown]
# ### 2.2 Decoder Transformer Block
# A decoder block stacks two main sub-layers:
#
# 1. **Causal Self-Attention**
# 2. **Feed-Forward Network (MLP)**
#
# Both sub-layers use **residual connections** and **layer normalization**, which help the model stabilize learning.
#
# Practically, this module:
#
# - runs causal attention
# - adds a residual connection + layer normalization
# - applies a small feed-forward network
# - adds another residual connection + normalization
#
# This block is the main computational building unit of GPT-style models.
#
# **Important**: This is a Post-Norm decoder block, as the normalization is applied after the transformations.

# %%
class DecoderBlock(nn.Module):
    def __init__(self, d_model=256, num_heads=4, hidden_dim=512, dropout=0.1):
        super().__init__()
        self.att = CausalSelfAttention(d_model, num_heads)
        self.norm1 = nn.LayerNorm(d_model)

        # The feed forward network
        self.ff = nn.Sequential(
            nn.Linear(d_model, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, d_model)
        )
        self.norm2 = nn.LayerNorm(d_model)

        # <-- Dropout used exactly like in GPT-style implementations
        self.dropout = nn.Dropout(dropout)

    def forward(self, x, pad_mask=None):
        # Residual connection 1 (self-attention)
        att_out = self.att(x, pad_mask=pad_mask)
        x = x + self.dropout(att_out)
        x = self.norm1(x)

        # Residual connection 2 (feed-forward network)
        ff_out = self.ff(x)
        x = x + self.dropout(ff_out)
        x = self.norm2(x)

        return x

# %% [markdown]
# ### 2.3 Mini GPT (LM Head)
# A GPT-style model takes token IDs, turns them into embedding vectors, processes them through several decoder blocks, and then predicts the next token at every position.
#
# Practically, our Mini GPT model includes:
#
# - a token embedding layer
# - one or more decoder blocks
# - a final linear projection (“LM head”) mapping hidden states to vocabulary logits
#
# The LM head outputs a *probability distribution* over the next token.
# Training this model with cross-entropy on next-token prediction gives us a working, miniature GPT.

# %%
class MiniGPT(nn.Module):
    def __init__(self, vocab_size, d_model=256, num_layers=2, max_len=48, hidden_dim=512, num_heads=4):
        super().__init__()
        # token embeddings
        self.token_emb = nn.Embedding(vocab_size, d_model)
        # positional embeddings
        self.pos_emb   = nn.Embedding(max_len, d_model)
        # stacked decoder blocks (num_layers)
        self.blocks = nn.ModuleList([
            DecoderBlock(d_model=d_model, num_heads=num_heads, hidden_dim=hidden_dim)
            for _ in range(num_layers)
        ])

        # Final normalization before prediction
        self.ln_f = nn.LayerNorm(d_model)
        
        # Convert hidden states into vocabulary scores (logits)
        self.lm_head = nn.Linear(d_model, vocab_size)

    def forward(self, idx):
        B, T = idx.shape

        # compute the combined token + positional embedding for each 
        # token in the input sequence
        pos = torch.arange(T, device=idx.device).unsqueeze(0)
        x = self.token_emb(idx) + self.pos_emb(pos)
    
        # Mark padding tokens so attention can ignore them
        pad_mask = (idx == pad_idx)

        # Pass the sequence through each decoder block
        for block in self.blocks:
            x = block(x, pad_mask=pad_mask)

        # Final normalization and prediction of next-token scores
        x = self.ln_f(x)
        return self.lm_head(x)

# %% [markdown]
# ## 3. Training
#
# We train our Mini GPT model using the standard **next-token prediction** objective.
# For each window of tokens, the model sees positions `0 … T-2` as input and learns
# to predict tokens `1 … T-1`.
# Training proceeds in mini-batches and we track both training and validation loss.

# %% [markdown]
# ### 3.1 Training loop
#
# The training loop repeatedly:
# 1. forms batches of token windows
# 2. feeds inputs into the model
# 3. computes next-token prediction loss
# 4. performs a gradient update
# 5. reports training and validation loss per epoch
#
# Practically, the code below:
# - uses Adam for optimization
# - ignores `<pad>` tokens in the loss
# - prints deltas (Δ) to monitor convergence
# - stores the history for later visualization

# %%
from tqdm.notebook import tqdm

def train_lm(model, train_seqs, val_seqs,
             batch_size=32, num_epochs=30, lr=8e-4, weight_decay = 0.0):

    # Optimizer used to update the model parameters
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    # Ignore padding tokens when computing the loss
    pad_idx = stoi["<pad>"]
    criterion = nn.CrossEntropyLoss(ignore_index=pad_idx)

    history = []

    prev_train = None
    prev_val = None

    # Repeat the training process for several passes over the dataset
    for epoch in range(1, num_epochs + 1):

        # Shuffle training examples before each epoch
        random.shuffle(train_seqs)

        total_loss = 0.0
        num_batches = 0

        # Process the dataset one mini-batch at a time
        for i in tqdm(range(0, len(train_seqs), batch_size),
                      desc=f"Epoch {epoch}"):

            batch = train_seqs[i:i + batch_size]
            if len(batch) < batch_size:
                continue

            batch = torch.stack(batch).to(device)  # (B, T)

            # Teacher forcing:
            # input = all tokens except the last
            # target = same sequence shifted by one position
            inputs = batch[:, :-1]
            targets = batch[:, 1:]

            # Predict the next token at every position
            logits = model(inputs)

            # Compute next-token prediction loss
            # CrossEntropyLoss expects:
            #   logits : (N, num_classes)
            #   targets: (N,)
            #
            # We therefore flatten batch and time dimensions:
            #   (B, T, |V|) -> (B*T, |V|)
            #   (B, T)      -> (B*T)
            #
            # Each token position becomes one vocabulary
            # classification example.
            # Note: -1 here means 'infer dimension'
            loss = criterion(
                logits.reshape(-1, vocab_size), # (B, T, |V|) -> (B . T, |V|)
                targets.reshape(-1)             # (B, T)      -> (B . T)
            )

            # Standard training step:
            # clear gradients -> backpropagate -> update weights
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            total_loss += loss.item()
            num_batches += 1

        train_loss = total_loss / num_batches

        # Evaluate on unseen sequences to monitor generalization
        val_loss = evaluate_lm_loss(
            model, criterion, val_seqs,
            batch_size=batch_size
        )

        history.append((train_loss, val_loss))

        # Print losses and their change since the previous epoch
        if prev_train is None:
            print(
                f"Epoch {epoch:2d}/{num_epochs} — "
                f"train={train_loss:.4f}  val={val_loss:.4f}"
            )
        else:
            d_train = train_loss - prev_train
            d_val = val_loss - prev_val

            print(
                f"Epoch {epoch:2d}/{num_epochs} — "
                f"train={train_loss:.4f} (Δ {d_train:+.4f})  "
                f"val={val_loss:.4f} (Δ {d_val:+.4f})"
            )

        prev_train = train_loss
        prev_val = val_loss

    return history

# %% [markdown]
# ### 3.2 Evaluating loss on the validation dataset
#
# We measure how well the model generalizes by computing the same next-token loss on held-out data *without* updating weights.
#
# The function below:
# - switches the model to evaluation mode
# - iterates over validation windows
# - computes average cross-entropy loss
# - returns the scalar value used for monitoring training

# %%
def evaluate_lm_loss(model, criterion, val_seqs, batch_size=32):
    model.eval()
    total_loss = 0.0
    num_batches = 0

    with torch.no_grad():
        for i in range(0, len(val_seqs), batch_size):
            batch = val_seqs[i:i+batch_size]
            if len(batch) < batch_size:
                continue

            batch = torch.stack(batch).to(device)  # (B, T)
            inputs  = batch[:, :-1]   # (B, T-1)
            targets = batch[:, 1:]    # (B, T-1)

            logits = model(inputs)    # (B, T-1, V)
            loss = criterion(
                logits.reshape(-1, vocab_size),
                targets.reshape(-1)
            )

            total_loss += loss.item()
            num_batches += 1

    model.train()
    return total_loss / num_batches

# %% [markdown]
# ### 3.3 Initialising components and model parameters
#
# We select:
# - hidden size (`d_model`)
# - number of layers
# - number of attention heads
# - feed-forward dimension
# - context window length (`max_len`)
#
# These hyperparameters define the capacity of the model.
#
# Here, we instantiate our Mini GPT with reasonable dimensions for fast training.

# %%
d_model = 192
hidden_dim = 384
num_layers = 2
num_heads = 4
max_len   = seq_len

model = MiniGPT(vocab_size, d_model=d_model, num_layers=num_layers,
                max_len=max_len, hidden_dim=hidden_dim, num_heads=num_heads).to(device)
model

# %% [markdown]
# ### 3.4 Performing the training
#
# We now train the model for a small number of epochs to observe learning behaviour
# and track improvements in validation loss.

# %%
history = train_lm(model, train_seqs, eval_seqs,
                   batch_size=32, num_epochs=5, lr=5e-4)

# %% [markdown]
# ### 3.5 (Optional) Save trained weights
# We can optionally save the model to reuse later.

# %%
import torch

def save_checkpoint(model, stoi, itos, path="minigpt_checkpoint.pt"):
    checkpoint = {
        "model_state_dict": model.state_dict(),
        "stoi": stoi,
        "itos": itos,
        "config": {
            "vocab_size": model.token_emb.num_embeddings,
            "d_model": model.token_emb.embedding_dim,
            "num_layers": len(model.blocks),
            "max_len": model.pos_emb.num_embeddings,
            "hidden_dim": model.blocks[0].ff[0].out_features,
            "num_heads": model.blocks[0].att.num_heads
        }
    }
    torch.save(checkpoint, path)
    print(f"Saved checkpoint to: {path}")

# Example usage:
save_checkpoint(model, stoi, itos, path="minigpt_epoch30_lg_stream15_punkt.pt")

# %% [markdown]
# ### 3.5 Loading the pretrained model
# We can directly load the model previously saved with the above function.

# %%
def load_checkpoint(path="minigpt_checkpoint.pt"):
    checkpoint = torch.load(path, map_location=device)

    config = checkpoint["config"]
    stoi = checkpoint["stoi"]
    itos = checkpoint["itos"]

    # Recreate the model
    model = MiniGPT(
        vocab_size=config["vocab_size"],
        d_model=config["d_model"],
        num_layers=config["num_layers"],
        max_len=config["max_len"],
        hidden_dim=config["hidden_dim"],
        num_heads=config["num_heads"]
    ).to(device)

    # Load weights
    model.load_state_dict(checkpoint["model_state_dict"])
    model.eval()

    print(f"Loaded model from: {path}")
    return model, stoi, itos

# Example usage:
loaded_model, loaded_stoi, loaded_itos = load_checkpoint("minigpt_epoch30.pt")

# %% [markdown]
# ## 4. Testing our model
#
# Once the model is trained, we can test it by **sampling text** from it.
# This is the standard way to evaluate a decoder-only (GPT-style) model:  we provide a *prompt*, let the model predict the next token, append it, and repeat the process autoregressively.
#
# This section implements a simple sampling function and tests the model on a prompt.

# %% [markdown]
# ### 4.1 Sampling (autoregressive generation)
#
# - We feed the model a prompt (a sequence of token IDs).
# - The model predicts the distribution of the next token.
# - We sample from this distribution (optionally using temperature).
# - We append the sampled token to the sequence and continue.
#
# The functions below:
# - handles tokenization and detokenization
# - runs the autoregressive loop
# - supports temperature for controlling randomness
# - ensures we keep only the last `seq_len` tokens when generating

# %%
def decode_ids(ids):
    return [itos[i] for i in ids]

def encode_tokens(tokens):
    return torch.tensor([stoi.get(t, stoi["<unk>"]) for t in tokens], dtype=torch.long)

# %%
# Generate text by repeatedly predicting the next token
def generate_sample(model, prompt, max_new_tokens=60, temperature=1.0):
    model.eval()

    # Temperature controls randomness:
    # smaller -> more deterministic
    # larger  -> more diverse/random
    if temperature <= 0:
        raise ValueError("temperature must be > 0")

    # Use the context length the model was trained with
    context_len = model.pos_emb.num_embeddings

    # Convert prompt into token ids
    tokens = [stoi.get(tok, stoi["<unk>"]) for tok in simple_tokenize(prompt)]

    # If the prompt is too long, keep the most recent tokens
    tokens = tokens[-context_len:]

    # Generate one token at a time
    for _ in range(max_new_tokens):

        # The model only sees the current context window
        x = torch.tensor(
            tokens[-context_len:],
            dtype=torch.long
        ).unsqueeze(0).to(device)

        # Predict the next-token distribution
        with torch.no_grad():
            logits = model(x)              # (1, T, V)
            next_logits = logits[:, -1, :]  # scores for the last position

            # Adjust the sharpness of the distribution
            next_logits = next_logits / temperature
            probs = F.softmax(next_logits, dim=-1)

        # Sample one token from the probability distribution
        next_id = torch.multinomial(probs, num_samples=1).item()

        # Append the new token and continue generating
        tokens.append(next_id)

    # Convert token ids back to words
    result = [itos[t] for t in tokens]
    return result

# %% [markdown]
# ### 4.2 Generating text from our model
#
# Now we test generation using a short *prompt*.
# Because our model is small, generation will not be perfect,
# but it should show coherent structure, punctuation, and topic flow.

# %%
prompt = "According to the game"

generated = generate_sample(model, prompt, max_new_tokens=64, temperature=.8)

text = " ".join(generated)      # join tokens
text = re.sub(" \.", ".", text) # remove spaces before .
text = re.sub(" \,", ",", text) # remove spaces before ,
text

# %% [markdown]
# ## 5. Evaluating Design Decisions
#
# The MiniGPT model exposes several design choices that affect what the model can learn and how well it generalizes.
#
# For each experiment:
#
# 1. Change **one parameter at a time**.
# 2. Train the model for a small number of epochs.
# 3. Record:
#    - training loss
#    - validation loss
#    - validation perplexity
# 4. Inspect a few generated samples.
# 5. Reflect on the behaviour you observe.
#
#
# Below there are a couple of helpers that will help you run the experiments.

# %%
import matplotlib.pyplot as plt

def run_experiment(
    name="baseline",
    d_model=192,
    num_layers=2,
    num_heads=4,
    hidden_dim=384,
    seq_len=64,
    dropout=0.1,
    batch_size=32,
    epochs=5,
    lr=5e-4,
    weight_decay=0.0,
    num_train_windows=None,
    generate=True,
    prompt="According to the game",
    max_new_tokens=64,
    temperature=0.8,
    plot_loss=False,
    verbose=True
):
    """
    Run one MiniGPT experiment and return the trained model,
    metrics, configuration, and optional generated sample.
    """

    train_windows = stream_to_windows(train_id_stream, seq_len, pad_idx)
    val_windows = stream_to_windows(eval_id_stream, seq_len, pad_idx)

    if num_train_windows is not None:
        train_windows = random.sample(
            train_windows,
            min(num_train_windows, len(train_windows))
        )

    model = MiniGPT(
        vocab_size=vocab_size,
        d_model=d_model,
        num_layers=num_layers,
        max_len=seq_len,
        hidden_dim=hidden_dim,
        num_heads=num_heads
    ).to(device)

    if verbose:
        print("\n=== Running experiment ===")
        print(f"name        : {name}")
        print(f"d_model     : {d_model}")
        print(f"layers      : {num_layers}")
        print(f"heads       : {num_heads}")
        print(f"hidden_dim  : {hidden_dim}")
        print(f"seq_len     : {seq_len}")
        print(f"dropout     : {dropout}")
        print(f"epochs      : {epochs}")
        print("---------------------------")

    history = train_lm(
        model,
        train_windows,
        val_windows,
        batch_size=batch_size,
        num_epochs=epochs,
        lr=lr,
        weight_decay=weight_decay
    )

    train_losses = [h[0] for h in history]
    val_losses = [h[1] for h in history]

    final_train_loss = train_losses[-1]
    final_val_loss = val_losses[-1]
    final_val_ppl = math.exp(final_val_loss)

    if plot_loss:
        plt.figure(figsize=(6, 4))
        plt.plot(train_losses, label="Training loss")
        plt.plot(val_losses, label="Validation loss")
        plt.title(name)
        plt.xlabel("Epoch")
        plt.ylabel("Cross-entropy loss")
        plt.legend()
        plt.grid(True)
        plt.show()

    generated_text = None

    if generate:
        generated = generate_sample(
            model,
            prompt,
            max_new_tokens=max_new_tokens,
            temperature=temperature
        )
        generated_text = " ".join(generated)
        print("\nSample:")
        print(generated_text)

    return {
        "name": name,
        "model": model,
        "config": {
            "d_model": d_model,
            "num_layers": num_layers,
            "num_heads": num_heads,
            "hidden_dim": hidden_dim,
            "seq_len": seq_len,
            "dropout": dropout,
            "batch_size": batch_size,
            "epochs": epochs,
            "lr": lr,
            "train_windows": len(train_windows),
            "val_windows": len(val_windows),
        },
        "history": history,
        "train_loss": final_train_loss,
        "val_loss": final_val_loss,
        "val_ppl": final_val_ppl,
        "generated_text": generated_text,
    }

# %% [markdown]
# Some helpers to plot and summarise the results.

# %%
import pandas as pd

def summarize_experiments(results):
    """
    Convert experiment outputs into a pandas DataFrame.
    """

    rows = []

    for r in results:
        row = {
            "name": r["name"],
            "train_loss": r["train_loss"],
            "val_loss": r["val_loss"],
            "val_ppl": r["val_ppl"],
        }

        row.update(r["config"])
        rows.append(row)

    return pd.DataFrame(rows)

    
def plot_performance_matrix(results, metric="val_ppl"):
    """
    Plot a compact comparison of experiments.

    Useful metrics:
        - "train_loss"
        - "val_loss"
        - "val_ppl"
    """

    df = summarize_experiments(results)

    df = df.sort_values(metric, ascending=True)

    plt.figure(figsize=(9, 5))
    plt.barh(df["name"], df[metric])
    plt.xlabel(metric)
    plt.title(f"Experiment comparison by {metric}")
    plt.gca().invert_yaxis()
    plt.grid(axis="x", alpha=0.3)
    plt.show()

    return df

# %% [markdown]
# ### Experiment 1 – Model Capacity
#
# **Question:** How does model capacity affect learning and generalization?
#
# Try:
#
# ```python
# # A. Increase the representation size
# d_model = 128, 256, 384
#
# # B. Fix d_model and vary the feed-forward network
# hidden_dim = d_model, 2 * d_model, 4 * d_model
#
# # C. Fix a larger d_model and vary attention heads
# num_heads = 2, 4, 8
# ```
#
# **Reflect:**
#
# - Which changes improve validation perplexity?
# - When do additional parameters stop helping?
# - Which configurations show underfitting or overfitting?
# - Does generated text quality always match perplexity?

# %%
capacity_configs = [
    # 1A. Increase model dimension
    { "name": "small d_model", "d_model": 128, "hidden_dim": 256, "num_heads": 4, "num_layers": 2,},
    { "name": "medium d_model","d_model": 192, "hidden_dim": 384, "num_heads": 4, "num_layers": 2,},
    { "name": "large d_model", "d_model": 256, "hidden_dim": 512, "num_heads": 4, "num_layers": 2,},

    # 1B. Same d_model, larger feed-forward layer
    { "name": "d192 ff small",  "d_model": 192, "hidden_dim": 192, "num_heads": 4, "num_layers": 2,},
    { "name": "d192 ff medium", "d_model": 192, "hidden_dim": 384, "num_heads": 4, "num_layers": 2,},
    { "name": "d192 ff large",  "d_model": 192, "hidden_dim": 768, "num_heads": 4, "num_layers": 2,},

    # 1C. Same larger d_model, different number of heads
    { "name": "d256 heads 2", "d_model": 256, "hidden_dim": 512, "num_heads": 2, "num_layers": 2, },
    { "name": "d256 heads 4", "d_model": 256, "hidden_dim": 512, "num_heads": 4, "num_layers": 2, },
    { "name": "d256 heads 8", "d_model": 256, "hidden_dim": 512, "num_heads": 8, "num_layers": 2, },
]

results = []

for cfg in capacity_configs:
    out = run_experiment(
        **cfg,
        seq_len=64,
        dropout=0.1,
        batch_size=32,
        epochs=8,
        lr=5e-4,
        generate=False,
        plot_loss=False
    )
    results.append(out)

# %%
df_results = plot_performance_matrix(results, metric="val_ppl")
df_results

# %% [markdown]
# ### Experiment 2 – Model Depth
#
# **Question:** Does stacking more decoder blocks improve the language model?
#
# Try:
#
# ```python
# num_layers = 1
# num_layers = 2
# num_layers = 4
# ```
#
# **Reflect:**
#
# - Does adding layers improve validation performance?
# - Do deeper models require more epochs to train?
# - Does generation become more coherent?
# - Is there a point where adding layers gives little benefit?

# %%
depth_configs = [
    {"name": "1 layer", "d_model": 192, "hidden_dim": 384, "num_heads": 4, "num_layers": 1},
    {"name": "2 layers", "d_model": 192, "hidden_dim": 384, "num_heads": 4, "num_layers": 2},
    {"name": "4 layers", "d_model": 192, "hidden_dim": 384, "num_heads": 4, "num_layers": 4},
]

results = []

for cfg in depth_configs:
    out = run_experiment(
        **cfg,
        seq_len=64,
        dropout=0.1,
        batch_size=32,
        epochs=8,
        lr=5e-4,
        generate=False,
        plot_loss=True
    )
    results.append(out)

# %%
df_results = plot_performance_matrix(results, metric="val_ppl")
df_results

# %% [markdown]
# ### Experiment 3 – Context Window Length
#
# **Question:** Does giving the model more context improve language modelling?
#
# Try:
#
# ```python
# seq_len = 16
# seq_len = 64
# ```
#
# Keep the other parameters fixed:
#
# ```python
# d_model = 192
# hidden_dim = 384
# num_heads = 4
# num_layers = 2
# ```
#
# **Reflect:**
#
# - Does the larger context improve validation perplexity?
# - Does training become slower?
# - Does generated text become more coherent?
# - Why might some dependencies require a longer context window?

# %%
context_configs = [{"name": "short context (16)", "seq_len": 16}, 
                   {"name": "long context (64)", "seq_len": 64}]

results = []
for cfg in context_configs:
    out = run_experiment(
        **cfg,
        d_model=192,
        hidden_dim=384,
        num_heads=4,
        num_layers=2,
        batch_size=32,
        epochs=5,
        plot_loss=True,
    )
    results.append(out)

# %%
df_results = plot_performance_matrix(results, metric="val_ppl")
df_results

# %% [markdown]
# ### Experiment 4 – Dropout and Generalization
#
# **Question:** Can dropout and weight decay help prevent overfitting?
#
# Try:
#
# ```python
# dropout = 0.0, weight_decay =  0
# dropout = 0.1, weight_decay =  1e-4
# dropout = 0.3, weight_decay =  1e-4
# ```
#
# **Reflect:**
#
# - Which model obtains the lowest training loss?
# - Which model obtains the lowest validation loss?
# - Does some dropout improve generalization?
# - What happens when too much dropout is used?

# %%
# TODO: try weight decay as well
dropout_configs = [{"name": "no dropout", "dropout": 0.0, "weight_decay": 0.0}, 
                   {"name": "moderate dropout", "dropout": 0.1, "weight_decay": 1e-4}, 
                   {"name": "high dropout", "dropout": 0.3, "weight_decay": 1e-4}]

results = []
for cfg in dropout_configs:
    out = run_experiment(
        **cfg,
        d_model=256,
        hidden_dim=512,
        num_heads=8,
        num_layers=4,
        seq_len=64,
        batch_size=32,
        epochs=10,
        plot_loss=True,
    )
    results.append(out)

# %%
df_results = plot_performance_matrix(results, metric="val_ppl")
df_results
